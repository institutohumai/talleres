# %%
import gradio
gradio.__version__
# Out:
# '3.25.0'

# %%
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone -b v1.2 https://github.com/camenduru/text-generation-webui.git
# %cd /content/text-generation-webui
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'text-generation-webui' already exists and is not an empty directory.
# /content/text-generation-webui
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'

# %%
# !mkdir /content/text-generation-webui/repositories
# %cd /content/text-generation-webui/repositories
# !git clone -b v1.2 https://github.com/camenduru/GPTQ-for-LLaMa.git
# %cd GPTQ-for-LLaMa
# !python setup_cuda.py install

drive_folder = '/content/drive/MyDrive/text-generation-webui'
if not os.path.exists(drive_folder):
    os.makedirs(drive_folder)
# !mv /content/text-generation-webui/* "$drive_folder/"
# Out:
# /content/text-generation-webui/repositories
# Cloning into 'GPTQ-for-LLaMa'...
# remote: Enumerating objects: 832, done.
# remote: Counting objects: 100% (832/832), done.
# remote: Compressing objects: 100% (331/331), done.
# remote: Total 832 (delta 502), reused 805 (delta 496), pack-reused 0
# Receiving objects: 100% (832/832), 487.29 KiB | 14.33 MiB/s, done.
# Resolving deltas: 100% (502/502), done.
# /content/text-generation-webui/repositories/GPTQ-for-LLaMa
# running install
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# /usr/local/lib/python3.10/dist-packages/setuptools/_distutils/cmd.py:66: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer, pypa/build or
#         other standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running bdist_egg
# running egg_info
# creating quant_cuda.egg-info
# writing quant_cuda.egg-info/PKG-INFO
# writing dependency_links to quant_cuda.egg-info/dependency_links.txt
# writing top-level names to quant_cuda.egg-info/top_level.txt
# writing manifest file 'quant_cuda.egg-info/SOURCES.txt'
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:476: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'quant_cuda.egg-info/SOURCES.txt'
# writing manifest file 'quant_cuda.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:398: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 11.8
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'quant_cuda' extension
# creating build
# creating build/temp.linux-x86_64-cpython-310
# x86_64-linux-gnu-gcc -pthread -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c quant_cuda.cpp -o build/temp.linux-x86_64-cpython-310/quant_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=quant_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++17
# /usr/local/cuda/bin/nvcc -I/usr/local/lib/python3.10/dist-packages/torch/include -I/usr/local/lib/python3.10/dist-packages/torch/include/torch/csrc/api/include -I/usr/local/lib/python3.10/dist-packages/torch/include/TH -I/usr/local/lib/python3.10/dist-packages/torch/include/THC -I/usr/local/cuda/include -I/usr/include/python3.10 -c quant_cuda_kernel.cu -o build/temp.linux-x86_64-cpython-310/quant_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options '-fPIC' -DTORCH_API_INCLUDE_EXTENSION_H -DPYBIND11_COMPILER_TYPE=\"_gcc\" -DPYBIND11_STDLIB=\"_libstdcpp\" -DPYBIND11_BUILD_ABI=\"_cxxabi1011\" -DTORCH_EXTENSION_NAME=quant_cuda -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_75,code=compute_75 -gencode=arch=compute_75,code=sm_75 -std=c++17
# /usr/local/lib/python3.10/dist-packages/torch/include/c10/util/irange.h(54): warning #186-D: pointless comparison of unsigned integer with zero
#           detected during:
#             instantiation of "__nv_bool c10::detail::integer_iterator<I, one_sided, <unnamed>>::operator==(const c10::detail::integer_iterator<I, one_sided, <unnamed>> &) const [with I=size_t, one_sided=false, <unnamed>=0]"
# (61): here
#             instantiation of "__nv_bool c10::detail::integer_iterator<I, one_sided, <unnamed>>::operator!=(const c10::detail::integer_iterator<I, one_sided, <unnamed>> &) const [with I=size_t, one_sided=false, <unnamed>=0]"
# /usr/local/lib/python3.10/dist-packages/torch/include/c10/core/TensorImpl.h(77): here
#
# /usr/local/lib/python3.10/dist-packages/torch/include/c10/util/irange.h(54): warning #186-D: pointless comparison of unsigned integer with zero
#           detected during:
#             instantiation of "__nv_bool c10::detail::integer_iterator<I, one_sided, <unnamed>>::operator==(const c10::detail::integer_iterator<I, one_sided, <unnamed>> &) const [with I=std::size_t, one_sided=true, <unnamed>=0]"
# (61): here
#             instantiation of "__nv_bool c10::detail::integer_iterator<I, one_sided, <unnamed>>::operator!=(const c10::detail::integer_iterator<I, one_sided, <unnamed>> &) const [with I=std::size_t, one_sided=true, <unnamed>=0]"
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/qualified_name.h(73): here
#
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:128:41: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                         ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:222:1: note: declared here
#   222 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:163: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                   ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Dispatch.h:122:1: note: declared here
#   122 | inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#       | ^~~~~~~~~~~
# quant_cuda_kernel.cu:128:163: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                   ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Dispatch.h:122:1: note: declared here
#   122 | inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#       | ^~~~~~~~~~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:128:1011: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:1032: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:1056: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:1083: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:1106: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:1129: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:128:2011: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:2032: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:2055: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:2081: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:2104: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:128:2127: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   128 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:214:41: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                         ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:222:1: note: declared here
#   222 |   DeprecatedTypeProperties & type() const {
#       | ^ ~~
# quant_cuda_kernel.cu:214:163: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                   ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Dispatch.h:122:1: note: declared here
#   122 | inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#       | ^~~~~~~~~~~
# quant_cuda_kernel.cu:214:163: warning: ‘c10::ScalarType detail::scalar_type(const at::DeprecatedTypeProperties&)’ is deprecated: passing at::DeprecatedTypeProperties to an AT_DISPATCH macro is deprecated, pass an at::ScalarType instead [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                   ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/Dispatch.h:122:1: note: declared here
#   122 | inline at::ScalarType scalar_type(const at::DeprecatedTypeProperties& t) {
#       | ^~~~~~~~~~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:214:1011: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:214:1032: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:214:1056: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:214:1083: warning: ‘T* at::Tensor::data() const [with T = double]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:214:1106: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:214:1129: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu: In lambda function:
# quant_cuda_kernel.cu:214:2011: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:214:2032: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:214:2055: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   214 |   AT_DISPATCH_FLOATING_TYPES(
# ...
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:445:2032: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   445 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:445:2055: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   445 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:445:2081: warning: ‘T* at::Tensor::data() const [with T = float]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   445 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:445:2104: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   445 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# quant_cuda_kernel.cu:445:2127: warning: ‘T* at::Tensor::data() const [with T = int]’ is deprecated: Tensor.data<T>() is deprecated. Please use Tensor.data_ptr<T>() instead. [-Wdeprecated-declarations]
#   445 |   AT_DISPATCH_FLOATING_TYPES(
#       |                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               ^
# /usr/local/lib/python3.10/dist-packages/torch/include/ATen/core/TensorBody.h:244:1: note: declared here
#   244 |   T * data() const {
#       | ^ ~~
# creating build/lib.linux-x86_64-cpython-310
# x86_64-linux-gnu-g++ -pthread -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 build/temp.linux-x86_64-cpython-310/quant_cuda.o build/temp.linux-x86_64-cpython-310/quant_cuda_kernel.o -L/usr/local/lib/python3.10/dist-packages/torch/lib -L/usr/local/cuda/lib64 -L/usr/lib/x86_64-linux-gnu -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda -o build/lib.linux-x86_64-cpython-310/quant_cuda.cpython-310-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# copying build/lib.linux-x86_64-cpython-310/quant_cuda.cpython-310-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg
# creating stub loader for quant_cuda.cpython-310-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/quant_cuda.py to quant_cuda.cpython-310.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying quant_cuda.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying quant_cuda.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying quant_cuda.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying quant_cuda.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# __pycache__.quant_cuda.cpython-310: module references __file__
# creating dist
# creating 'dist/quant_cuda-0.0.0-py3.10-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing quant_cuda-0.0.0-py3.10-linux-x86_64.egg
# removing '/usr/local/lib/python3.10/dist-packages/quant_cuda-0.0.0-py3.10-linux-x86_64.egg' (and everything under it)
# creating /usr/local/lib/python3.10/dist-packages/quant_cuda-0.0.0-py3.10-linux-x86_64.egg
# Extracting quant_cuda-0.0.0-py3.10-linux-x86_64.egg to /usr/local/lib/python3.10/dist-packages
# quant-cuda 0.0.0 is already the active version in easy-install.pth
#
# Installed /usr/local/lib/python3.10/dist-packages/quant_cuda-0.0.0-py3.10-linux-x86_64.egg
# Processing dependencies for quant-cuda==0.0.0
# Finished processing dependencies for quant-cuda==0.0.0
# mv: inter-device move failed: '/content/text-generation-webui/repositories' to '/content/drive/MyDrive/text-generation-webui/repositories'; unable to remove target: Directory not empty

# %%
# !apt-get -y install -qq aria2

# %%
import subprocess

def download_file(url, path, filename):
    command = f"aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {url} -d {path} -o {filename}"
    print(f"Downloading {filename}...")
    subprocess.run(command, shell=True)
    print(f"{filename} downloaded successfully.")

model = "vicuna"  # Set this to "alpaca" to select the alpaca model
if model == "alpaca":
    base_url = "https://huggingface.co/anon8231489123/gpt4-x-alpaca-13b-native-4bit-128g"
    safetensors = "4bit-128g.safetensors"
elif model == "vicuna":
    base_url = "https://huggingface.co/anon8231489123/vicuna-13b-GPTQ-4bit-128g"
    safetensors = "vicuna-13b-4bit-128g.safetensors"
else:
    raise ValueError("Invalid model selected")

base_path = "/content/drive/MyDrive/text-generation-webui/models/gpt4-x-" + model + "-13b-native-4bit-128g"

download_file(f"{base_url}/raw/main/config.json", base_path, "config.json")
download_file(f"{base_url}/raw/main/generation_config.json", base_path, "generation_config.json")
download_file(f"{base_url}/raw/main/special_tokens_map.json", base_path, "special_tokens_map.json")
download_file(f"{base_url}/resolve/main/tokenizer.model", base_path, "tokenizer.model")
download_file(f"{base_url}/raw/main/tokenizer_config.json", base_path, "tokenizer_config.json")
download_file(f"{base_url}/resolve/main/{safetensors}", base_path, safetensors)
# Out:
# Downloading config.json...
# config.json downloaded successfully.
# Downloading generation_config.json...
# generation_config.json downloaded successfully.
# Downloading special_tokens_map.json...
# special_tokens_map.json downloaded successfully.
# Downloading tokenizer.model...
# tokenizer.model downloaded successfully.
# Downloading tokenizer_config.json...
# tokenizer_config.json downloaded successfully.
# Downloading vicuna-13b-4bit-128g.safetensors...
# vicuna-13b-4bit-128g.safetensors downloaded successfully.

# %%
# !pip install gradio==3.26.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gradio==3.26.0
#   Downloading gradio-3.26.0-py3-none-any.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 68.1 MB/s eta 0:00:00
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (23.1.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (3.8.4)
# Requirement already satisfied: altair>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (4.2.2)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (0.98.0)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (0.3.0)
# Collecting gradio-client==0.1.2 (from gradio==3.26.0)
#   Downloading gradio_client-0.1.2-py3-none-any.whl (286 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.1/286.1 kB 38.0 MB/s eta 0:00:00
# Requirement already satisfied: httpx in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (0.24.1)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (0.15.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (3.1.2)
# Requirement already satisfied: markdown-it-py[linkify]>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (2.2.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (2.1.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (3.7.1)
# Requirement already satisfied: mdit-py-plugins<=0.3.3 in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (0.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (1.22.4)
# Requirement already satisfied: orjson in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (3.9.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (1.5.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (9.5.0)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (1.10.9)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (0.25.1)
# Requirement already satisfied: python-multipart in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (0.0.6)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (2.27.1)
# Requirement already satisfied: semantic-version in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (2.10.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (4.6.3)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (0.22.0)
# Requirement already satisfied: websockets>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio==3.26.0) (11.0.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.1.2->gradio==3.26.0) (2023.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from gradio-client==0.1.2->gradio==3.26.0) (23.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair>=4.2.0->gradio==3.26.0) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair>=4.2.0->gradio==3.26.0) (4.3.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair>=4.2.0->gradio==3.26.0) (0.12.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.0->gradio==3.26.0) (3.12.2)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.13.0->gradio==3.26.0) (4.65.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.26.0) (0.1.2)
# Requirement already satisfied: linkify-it-py<3,>=1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py[linkify]>=2.0.0->gradio==3.26.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->gradio==3.26.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->gradio==3.26.0) (2022.7.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.26.0) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.26.0) (2.0.12)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.26.0) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.26.0) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.26.0) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.26.0) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->gradio==3.26.0) (1.3.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi->gradio==3.26.0) (0.27.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.26.0) (2023.5.7)
# Requirement already satisfied: httpcore<0.18.0,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.26.0) (0.17.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.26.0) (3.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx->gradio==3.26.0) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.26.0) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.26.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.26.0) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.26.0) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->gradio==3.26.0) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->gradio==3.26.0) (1.26.16)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from uvicorn->gradio==3.26.0) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn->gradio==3.26.0) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx->gradio==3.26.0) (3.7.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair>=4.2.0->gradio==3.26.0) (0.19.3)
# Requirement already satisfied: uc-micro-py in /usr/local/lib/python3.10/dist-packages (from linkify-it-py<3,>=1->markdown-it-py[linkify]>=2.0.0->gradio==3.26.0) (1.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->gradio==3.26.0) (1.16.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx->gradio==3.26.0) (1.1.1)
# Installing collected packages: gradio-client, gradio
#   Attempting uninstall: gradio-client
#     Found existing installation: gradio_client 0.2.7
#     Uninstalling gradio_client-0.2.7:
#       Successfully uninstalled gradio_client-0.2.7
#   Attempting uninstall: gradio
#     Found existing installation: gradio 3.25.0
#     Uninstalling gradio-3.25.0:
#       Successfully uninstalled gradio-3.25.0
# Successfully installed gradio-3.26.0 gradio-client-0.1.2

# %%
import os

# %cd /content/drive/MyDrive/text-generation-webui

auth_token_path = "/content/drive/MyDrive/text-generation-webui/auth_token.txt"

# Set your username and password here (or use the default)
user = "username"
password = "password"

#auth = input("Do you want to enable authentication? (yes/no): ")
auth = "no"

if auth.lower() == "yes":
    with open(auth_token_path, "w") as f:
        f.write(f"{user}:{password}")
    print("auth_token.txt created successfully.")

if os.path.exists(auth_token_path):
    # !python server.py --share --chat --wbits 4 --groupsize 128 --gradio-auth-path {auth_token_path}
else:
    # !python server.py --share --chat --wbits 4 --groupsize 128
# Out:
# /content/drive/MyDrive/text-generation-webui
# Gradio HTTP request redirected to localhost :)
# Warning: the gradio "share link" feature downloads a proprietary and
# unaudited blob to create a reverse tunnel. This is potentially dangerous.
#
# 2023-06-25 01:03:52.929514: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# bin /usr/local/lib/python3.10/dist-packages/bitsandbytes/libbitsandbytes_cuda118.so
# Loading gpt4-x-vicuna-13b-native-4bit-128g...
# Found the following quantized model: models/gpt4-x-vicuna-13b-native-4bit-128g/vicuna-13b-4bit-128g.safetensors
# Loading model ...
# Done.
# Loaded the model in 48.57 seconds.
# Loading the extension "gallery"... Ok.
# Running on local URL:  http://127.0.0.1:7860
